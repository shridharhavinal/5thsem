# %%
from pandas import DataFrame
df1 = DataFrame(
              [
                  ['Shridhar','Havinal','Full-time','administration',2,20000],
                  ['Omkar','Sharanarthi','intern','technical',1,5000],
                  ['Rahul','Badakuri','Full-time','administration',5,10000],
                  ['Shivanand','Pujari','part-time','technical',3,10000],
                  ['Santosh','Hanjagi','Full-time','Management',6,20000]
              ]
    ,columns=['First Name','Last Name','Type','Department','YoE','salary']
              )
df1
# Out:
#   First Name    Last Name       Type      Department  YoE  salary
# 0   Shridhar      Havinal  Full-time  administration    2   20000
# 1      Omkar  Sharanarthi     intern       technical    1    5000
# 2      Rahul     Badakuri  Full-time  administration    5   10000
# 3  Shivanand       Pujari  part-time       technical    3   10000
# 4    Santosh      Hanjagi  Full-time      Management    6   20000

# %% [markdown]
# Make a pivot table which shows average salary of each type of employee for each
# department

# %%
import pandas as pd
table=pd.pivot_table(df1,index='Type',columns='Department',values='salary')
table
# Out:
# Department  Management  administration  technical
# Type
# Full-time      20000.0         15000.0        NaN
# intern             NaN             NaN     5000.0
# part-time          NaN             NaN    10000.0

# %% [markdown]
# Make a pivot table which shows the sum and mean of the salaries of each type of
# employee and the number of employees of each type

# %%
table=pd.pivot_table(df1,index='Type',values='salary',aggfunc=['mean','sum','count'])
table
# Out:
#                    mean    sum  count
#                  salary salary salary
# Type
# Full-time  16666.666667  50000      3
# intern      5000.000000   5000      1
# part-time  10000.000000  10000      1

# %% [markdown]
# display a povit table to count survival by gender , categories wise age of various classes age 0-10 cat1, 10-30 cat2, 30-60 cat3, 60-80 cat4

# %%
import pandas as pd
df = pd.read_csv("dataset/titanic.csv",)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       NaN       1
# 2              3       NaN       3
# 3              4       NaN       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female   NaN      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('dataset/titanic.csv')
age = pd.cut(df['Age'], [0, 10, 30, 60, 80])
result = df.pivot_table('Survived', index=['Sex',age], columns='Pclass', aggfunc='count')
print(result)
# Out:
# Pclass            1   2    3
# Sex    Age
# female (0, 10]    1   8   22
#        (10, 30]  34  36   56
#        (30, 60]  46  30   22
#        (60, 80]   2   0    1
# male   (0, 10]    2   9   22
#        (10, 30]  24  43  151
#        (30, 60]  63  44   76
#        (60, 80]  12   3    4
