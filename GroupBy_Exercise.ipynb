# %% [markdown]
# import required libraries and read Titanic Dataset

# %%
import pandas as pd
import numpy as np
df = pd.           ('dataset/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       NaN       1
# 2              3       NaN       3
# 3              4       NaN       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female   NaN      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#It Describes the dataframe by calculating numerical Functions
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  887.000000  891.000000  713.000000  891.000000
# mean    446.000000    0.382187    2.308642   29.704306    0.523008
# std     257.353842    0.486196    0.836071   14.536033    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  888.000000
# mean     0.381594   32.282530
# std      0.806057   49.758986
# min      0.000000    0.000000
# 25%      0.000000    7.917700
# 50%      0.000000   14.456250
# 75%      0.000000   31.068750
# max      6.000000  512.329200

# %%
#It Print a concise summary of a DataFrame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     887 non-null    float64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          713 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         888 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 83.7+ KB

# %%
df.describe(include="object") #it descibes the specific dtype
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
#align on both row and column with diff
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
#It shows the columns present in a dataframe
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#It Shows the starting rows 
df.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       NaN       1
# 2            3       NaN       3
# 3            4       NaN       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female   NaN      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
#It checks that there is NaN value and return true when NaN is Present
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False      True   False  False  False  False  False  False   False
# 2          False      True   False  False  False   True  False  False   False
# 3          False      True   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
#It Shows the sum of NaN values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         4
# Pclass           0
# Name             0
# Sex              0
# Age            178
# SibSp            0
# Parch            0
# Ticket           0
# Fare             3
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].isnull().sum()
# Out:
# 178

# %%
df[['Age','Cabin']].isnull().sum()
# Out:
# Age      178
# Cabin    687
# dtype: int64

# %%
#The Drop () removes the specified column in a DF
df1 = df.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)
df1
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0.0       3    male  22.0      1      0   7.2500        S
# 1         NaN       1  female  38.0      1      0  71.2833        C
# 2         NaN       3  female   NaN      0      0      NaN        S
# 3         NaN       1  female  35.0      1      0  53.1000        S
# 4         0.0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886       0.0       2    male  27.0      0      0  13.0000        S
# 887       1.0       1  female  19.0      0      0  30.0000        S
# 888       0.0       3  female   NaN      1      2  23.4500        S
# 889       1.0       1    male  26.0      0      0  30.0000        C
# 890       0.0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df1.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  887.000000  891.000000  713.000000  891.000000  891.000000  888.000000
# mean     0.382187    2.308642   29.704306    0.523008    0.381594   32.282530
# std      0.486196    0.836071   14.536033    1.102743    0.806057   49.758986
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.000000    0.000000    0.000000    7.917700
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.456250
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.068750
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df1.isnull().sum()
# Out:
# Survived      4
# Pclass        0
# Sex           0
# Age         178
# SibSp         0
# Parch         0
# Fare          3
# Embarked      2
# dtype: int64

# %%
df2 = df1.fillna(method='ffill')
df2
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0.0       3    male  22.0      1      0   7.2500        S
# 1         0.0       1  female  38.0      1      0  71.2833        C
# 2         0.0       3  female  38.0      0      0  71.2833        S
# 3         0.0       1  female  35.0      1      0  53.1000        S
# 4         0.0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886       0.0       2    male  27.0      0      0  13.0000        S
# 887       1.0       1  female  19.0      0      0  30.0000        S
# 888       0.0       3  female  19.0      1      2  23.4500        S
# 889       1.0       1    male  26.0      0      0  30.0000        C
# 890       0.0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df2.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
#This can be used to group large amounts of data and compute operations on these groups.
survive=df2.groupby('Survived')['Survived'].count()#->Here the count is stored and doing separationa
survive
# Out:
# Survived
# 0.0    552
# 1.0    339
# Name: Survived, dtype: int64

# %%
survive=df2.groupby('Survived')['Survived'].count()#->Here the count is stored and doing separationa
survive

# %%
Pclass = df2.groupby('Pclass')['Survived'].count()
Pclass
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Survived, dtype: int64

# %%
Sex_count = df2.groupby('Sex')['Sex'].count()
Sex_count
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
Embark_count = df2.groupby('Embarked')['Embarked'].count()
Embark_count
# Out:
# Embarked
# C    169
# Q     78
# S    644
# Name: Embarked, dtype: int64

# %%
Survived_Sex = df2.groupby('Sex')['Survived'].sum()
Survived_Sex
# Out:
# Sex
# female    230.0
# male      109.0
# Name: Survived, dtype: float64

# %%
sex_count = df2.groupby(["Pclass","Survived","Sex"])['Survived'].count()
sex_count
# Out:
# Pclass  Survived  Sex
# 1       0.0       female      5
#                   male       77
#         1.0       female     89
#                   male       45
# 2       0.0       female      6
#                   male       91
#         1.0       female     70
#                   male       17
# 3       0.0       female     73
#                   male      300
#         1.0       female     71
#                   male       47
# Name: Survived, dtype: int64

# %%
sex_count = df2.groupby(["Sex","Survive d","Pclass"])['Survived'].count()
sex_count
# Out:
# Sex     Survived  Pclass
# female  0.0       1           5
#                   2           6
#                   3          73
#         1.0       1          89
#                   2          70
#                   3          71
# male    0.0       1          77
#                   2          91
#                   3         300
#         1.0       1          45
#                   2          17
#                   3          47
# Name: Survived, dtype: int64

# %%
df2
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0.0       3    male  22.0      1      0   7.2500        S
# 1         0.0       1  female  38.0      1      0  71.2833        C
# 2         0.0       3  female  38.0      0      0  71.2833        S
# 3         0.0       1  female  35.0      1      0  53.1000        S
# 4         0.0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886       0.0       2    male  27.0      0      0  13.0000        S
# 887       1.0       1  female  19.0      0      0  30.0000        S
# 888       0.0       3  female  19.0      1      2  23.4500        S
# 889       1.0       1    male  26.0      0      0  30.0000        C
# 890       0.0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df2['Survived'].sum()
# Out:
# 339.0

# %%
df2['Survived'].count()
# Out:
# 891

# %%
sex_count = df2.groupby(["Sex"])['Survived'].sum()
sex_count
# Out:
# Sex
# female    230.0
# male      109.0
# Name: Survived, dtype: float64

# %%
sex_count = df2.groupby(["Sex"])['Survived'].count()
sex_count
# Out:
# Sex
# female    314
# male      577
# Name: Survived, dtype: int64

# %%
#Survival Rate in 1st Class
sex_count = df2.groupby(["Sex"])['Survived'].sum()/ df2.groupby(["Sex"])['Survived'].count()*100
sex_count
# Out:
# Sex
# female    73.248408
# male      18.890815
# Name: Survived, dtype: float64

# %%
sex_count = df2.groupby(["Embarked","Survived"])['Survived'].sum()
sex_count
# Out:
# Embarked  Survived
# C         0.0           0.0
#           1.0          93.0
# Q         0.0           0.0
#           1.0          31.0
# S         0.0           0.0
#           1.0         215.0
# Name: Survived, dtype: float64
